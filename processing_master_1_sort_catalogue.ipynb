# %% [markdown]
# ## nested image classification
# ## Data processing part 1
#
# This is a notebook documenting the first part of the data processing on the image dataset provided by nested.

# %%
# import libraries and nested_utilities
import nested_utilities as nutil
import os
import shutil
import pandas as pd


# create a timestamped directory for this processing activity, a
# and corresponding image catalogues created
out_dir = os.path.join('./data_catalogues/processing_'+nutil.timestamp())
os.mkdir(out_dir)
#out_dir

# %% [markdown]
# Most of the code routines used in this notebook are in:
# ```nested_utilities.py```

# %% [markdown]
# ### 1. Initial 'source_data' transfer, directory rearrangement and non-image file deletion
#
# This will take the 'raw' data as provided in:
#
# `tagged-property-images-20180304/`
#
# and move it into
#
# `data/base_data_NEW/`
#
# The directory
#
# `./data/`
#
# needs to exist before this code is run.

# %%
# basic initial configuration - moves directory, renames Misc (to _int and _ext)
# creates 'uncertain' dir
# moves dirs out of interior/ and exterior/ and deletes them
# removes non-.jpg files
# all created in ./data/base_data_NEW/


source_path = './archive/tagged-property-images-20180304'
nutil.configure_base_directory(source_path)
# Out:
# Moving directory
# Renaming misc directories
# Creating 'uncertain' & 'graphic' directory
# Move room directories out of /interior & /exterior
# Deleting /interior and /exterior
# Deleting non *.jpg files
# Removed 20328 non .jpg files

# %% [markdown]
# To avoid deleting data by mistake, any existing `base_data/` catalogue is renamed, and then the newly created directory is promoted to `base_data/`

# %%
# promotes 'base_data_NEW' to 'base_data', and renames old base_data to 'base_data_OLD

nutil.promote_new_base_dir('./data/base_data_NEW/')

# %% [markdown]
# ### 2. Catalogue ./base_data/, find any duplicates, remove them, and re-catalogue
#
# The first task is to produce a 'starting point' catalogue of the data using
# `nutil.build_catalogue`. And then check for any duplicates.

# %%
# catalogues base_data folders
base_data_cat = nutil.build_catalogue('./data/base_data/')
#base_data_cat.to_csv(os.path.join(out_dir, 'base_data_with_dupes.csv'))
print(base_data_cat.shape)
print(base_data_cat.info())

base_data_cat.sample(12).head(12)
# Out:
#                                              id      room  \
# 4852   0890449e472ae76b7a96c825297d327e368acc7a   bedroom
# 7946   0836501e8728f574bd5a10a35b2458681f406672     empty
# 1133   0760416ee502259aa4abb3c284e198f97e71225d  bathroom
# 3617   06aaf072af5b92d42618178e5c8cadc54f50d750   bedroom
# 2418   01c58f202b165f2c9e493e1a7c0d35db334ec089   bedroom
# 10565  116455cf80090879359be9a55254bf3ac37b5059     front
# 699    0652b6d568ff3422b6f9d73c9c795bba20b83030  bathroom
# 1788   08ea1f59c0af861c5576323b6734455d9e99c53a  bathroom
# 5422   205acf42212711a77c682ba6541622ba932da0b9   bedroom
# 12928  057755d7cbb36e42ec45438f955c04f1215d48e3   kitchen
# 1922   0934071a52e359efe9a55b60ac2225f57a898cd4  bathroom
# 3932   072ce73378318030faa6142ecc71226cb625b967   bedroom
#
#                                            filename  \
# 4852   0890449e472ae76b7a96c825297d327e368acc7a.jpg
# 7946   0836501e8728f574bd5a10a35b2458681f406672.jpg
# 1133   0760416ee502259aa4abb3c284e198f97e71225d.jpg
# 3617   06aaf072af5b92d42618178e5c8cadc54f50d750.jpg
# 2418   01c58f202b165f2c9e493e1a7c0d35db334ec089.jpg
# 10565  116455cf80090879359be9a55254bf3ac37b5059.jpg
# 699    0652b6d568ff3422b6f9d73c9c795bba20b83030.jpg
# 1788   08ea1f59c0af861c5576323b6734455d9e99c53a.jpg
# 5422   205acf42212711a77c682ba6541622ba932da0b9.jpg
# 12928  057755d7cbb36e42ec45438f955c04f1215d48e3.jpg
# 1922   0934071a52e359efe9a55b60ac2225f57a898cd4.jpg
# 3932   072ce73378318030faa6142ecc71226cb625b967.jpg
#
#                                               image_path
# 4852   ./data/base_data/bedroom/0890449e472ae76b7a96c...
# 7946   ./data/base_data/empty/0836501e8728f574bd5a10a...
# 1133   ./data/base_data/bathroom/0760416ee502259aa4ab...
# 3617   ./data/base_data/bedroom/06aaf072af5b92d426181...
# 2418   ./data/base_data/bedroom/01c58f202b165f2c9e493...
# 10565  ./data/base_data/front/116455cf80090879359be9a...
# 699    ./data/base_data/bathroom/0652b6d568ff3422b6f9...
# 1788   ./data/base_data/bathroom/08ea1f59c0af861c5576...
# 5422   ./data/base_data/bedroom/205acf42212711a77c682...
# 12928  ./data/base_data/kitchen/057755d7cbb36e42ec454...
# 1922   ./data/base_data/bathroom/0934071a52e359efe9a5...
# 3932   ./data/base_data/bedroom/072ce73378318030faa61...

# %%
# finds any duplicates
id_val_counts = base_data_cat['id'].value_counts()
duplicates = id_val_counts.loc[id_val_counts > 1]
duplicates
# Out:
# 02a55bf3e3f81df999b6afde2c1cecdebeaca619    2
# 00b2c17a73354413bbaf825a929b1263d63000c9    2
# Name: id, dtype: int64

# %%
duplicates_df = base_data_cat.loc[base_data_cat['id'].isin(duplicates.index)].copy()
duplicates_df.reset_index(inplace=True)
duplicates_df.drop('index', axis=1, inplace=True)
duplicates_df.to_csv(os.path.join(out_dir, 'duplicate_data.csv'))

duplicates_df
# Out:
#                                          id          room  \
# 0  00b2c17a73354413bbaf825a929b1263d63000c9  conservatory
# 1  00b2c17a73354413bbaf825a929b1263d63000c9    diningroom
# 2  02a55bf3e3f81df999b6afde2c1cecdebeaca619      entrance
# 3  02a55bf3e3f81df999b6afde2c1cecdebeaca619         front
#
#                                        filename  \
# 0  00b2c17a73354413bbaf825a929b1263d63000c9.jpg
# 1  00b2c17a73354413bbaf825a929b1263d63000c9.jpg
# 2  02a55bf3e3f81df999b6afde2c1cecdebeaca619.jpg
# 3  02a55bf3e3f81df999b6afde2c1cecdebeaca619.jpg
#
#                                           image_path
# 0  ./data/base_data/conservatory/00b2c17a73354413...
# 1  ./data/base_data/diningroom/00b2c17a73354413bb...
# 2  ./data/base_data/entrance/02a55bf3e3f81df999b6...
# 3  ./data/base_data/front/02a55bf3e3f81df999b6afd...

# %% [markdown]
# Now delete the duplicate files:

# %%
# '00b2c17a73354413bbaf825a929b1263d63000c9.jpg' is a conservatory
# '02a55bf3e3f81df999b6afde2c1cecdebeaca619.jpg' is a 'front' (though uncertain ...)
# So delete the rows with the 'other' label ([1,2])

idx_to_delete = [1,2]
path_to_delete = []
for img in idx_to_delete:
    path_to_delete.append(duplicates_df.iloc[img,3])

for file in path_to_delete:
    try: 
        os.remove(file)
        print('deleted file {}'.format(file))
    except OSError:
        pass
# Out:
# deleted file ./data/base_data/diningroom/00b2c17a73354413bbaf825a929b1263d63000c9.jpg
# deleted file ./data/base_data/entrance/02a55bf3e3f81df999b6afde2c1cecdebeaca619.jpg

# %% [markdown]
# And now recatalogue and recheck for duplicates to make sure we got them all.

# %%
# Now re-index again
# catalogues base_data folders

base_data_cat = nutil.build_catalogue('./data/base_data/')
#base_data_cat.to_csv(os.path.join(out_dir, 'base_data_no_dupes.csv'))

base_data_cat.sample(12).head(12)
# Out:
#                                              id        room  \
# 11458  0650295c6e572739cba1250c3507e5f1ff084b1d      garden
# 13953  078c93fe515a57bb57038456ef3b0a5d8e3f1306     kitchen
# 2974   05aedea91252c032233e89b398fe97263aeb46e6     bedroom
# 3024   05bc8fb5610c1ef2b314bf7629be33bb0c04c146     bedroom
# 2883   058ec08f35ca491d215e1bbbb0f8bdcdcba873e5     bedroom
# 12035  082e735cacbe58155d55fa952a2b0df42f68ef79      garden
# 3690   06cadd9f86fb6635deb1441f9c0b28ca8b623a79     bedroom
# 17717  24566d3cbf900613fc6f0d3f512c5b51f6f60ae9  livingroom
# 14519  08d14066227d4ff966d0799c46a2849e71ef4c53     kitchen
# 11648  06de16bd2385b549c698dca1dad3763519601c83      garden
# 2784   05604d69632a3ef75eb316e0b2cb70b89e6c266f     bedroom
# 18903  095279d9f988317e88d176d4a286bd8ad8a973c8    misc_ext
#
#                                            filename  \
# 11458  0650295c6e572739cba1250c3507e5f1ff084b1d.jpg
# 13953  078c93fe515a57bb57038456ef3b0a5d8e3f1306.jpg
# 2974   05aedea91252c032233e89b398fe97263aeb46e6.jpg
# 3024   05bc8fb5610c1ef2b314bf7629be33bb0c04c146.jpg
# 2883   058ec08f35ca491d215e1bbbb0f8bdcdcba873e5.jpg
# 12035  082e735cacbe58155d55fa952a2b0df42f68ef79.jpg
# 3690   06cadd9f86fb6635deb1441f9c0b28ca8b623a79.jpg
# 17717  24566d3cbf900613fc6f0d3f512c5b51f6f60ae9.jpg
# 14519  08d14066227d4ff966d0799c46a2849e71ef4c53.jpg
# 11648  06de16bd2385b549c698dca1dad3763519601c83.jpg
# 2784   05604d69632a3ef75eb316e0b2cb70b89e6c266f.jpg
# 18903  095279d9f988317e88d176d4a286bd8ad8a973c8.jpg
#
#                                               image_path
# 11458  ./data/base_data/garden/0650295c6e572739cba125...
# 13953  ./data/base_data/kitchen/078c93fe515a57bb57038...
# 2974   ./data/base_data/bedroom/05aedea91252c032233e8...
# 3024   ./data/base_data/bedroom/05bc8fb5610c1ef2b314b...
# 2883   ./data/base_data/bedroom/058ec08f35ca491d215e1...
# 12035  ./data/base_data/garden/082e735cacbe58155d55fa...
# 3690   ./data/base_data/bedroom/06cadd9f86fb6635deb14...
# 17717  ./data/base_data/livingroom/24566d3cbf900613fc...
# 14519  ./data/base_data/kitchen/08d14066227d4ff966d07...
# 11648  ./data/base_data/garden/06de16bd2385b549c698dc...
# 2784   ./data/base_data/bedroom/05604d69632a3ef75eb31...
# 18903  ./data/base_data/misc_ext/095279d9f988317e88d1...

# %%
# checks on duplicates remaining
# should return an empty series

id_val_counts_2 = base_data_cat['id'].value_counts()
id_val_counts_2.loc[id_val_counts_2 > 1]
# Out:
# Series([], Name: id, dtype: int64)

# %%
print(base_data_cat.shape)
print(base_data_cat.info())
# Out:
# (20529, 4)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20529 entries, 0 to 20528
# Data columns (total 4 columns):
# id            20529 non-null object
# room          20529 non-null object
# filename      20529 non-null object
# image_path    20529 non-null object
# dtypes: object(4)
# memory usage: 641.6+ KB
# None

# %% [markdown]
# ### 3. MANUAL STEP
#
# This is the first step of manual sorting - reviewing each classification folder in turn and removing any image that is wrongly classified or questionable into a holding folder called `uncertain/`.
#
#
# Go through each folder, and move anything where label is incorrect / innappropriate into
# 'uncertain' folder.

# %% [markdown]
# bathroom - DONE
# bedroom - DONE
# carpark - DONE
# conservatory - DONE
# diningroom - DONE
# NOTE - Lots of ambiguous images in diningroom. Aimed for photos where 'principal focus was an areas for sitting & eating'.
#
#
# empty - DONE
# entrance - DONE - again, quite a lot of ambiguity - and a lot of variability
#
# front - DONE
# NOTE - not sure on how to handle more 'detail' pics ofr front doors - front or misc-ext. tbd.
#
# garden - DONE
# ony a few changes
#
# kitchen - DONE
# quite a few changes - mainly around kitchen / dining room ambiguity ...
#
#
# livingroom - DONE
# some changes. Some mislabelling (from bedrooms). Some ambiguity (typically from diningroom, or bedroom)
#
# misc_ext - DONE
# A lot of mislabelling. Lots of 'graphic', lots of 'gardens' and a few 'carparks'. Also quite a lot of ambiguity on some images vs. 'front'.   Also quite a few misc-int.
#
# misc_int - DONE
# Again, a lot of mislabelling. Lots of graphics, lots of external. A few mislabelled rooms.
#
# rear - DONE
# A lot of ambiguity here. Hard to distinguish between garden / misc_ext / carpark and rear. Have tried to focus 'rear' on photos mainly of the rear of the property (commonly from garden).
#
# study - DONE
# Quite a lot of changes - 'study' is open to interpretation. Tend to refine to clear presence of desk & chair (or equivalent) and functioning as a working study-type room.

# %% [markdown]
# ### 4. WHEN MANUAL SORTING COMPLETE
#
# Re-catalogue with images in 'uncertain' folder, filter the df down to **just** the uncertatain rooms, and then merge data from the original catalogue to show their **original** room classification.
#
# Then handle a couple of duplication issues resulting (see cell comments).

# %%
uncertain_data_cat = nutil.build_catalogue('./data/base_data/')
#uncertain_data_cat.to_csv(os.path.join(out_dir, '090318_uncertain_sort_X.csv'))

# %%
# filter down to JUST uncertain rooms
uncertain_data_cat = uncertain_data_cat.loc[uncertain_data_cat['room'] == 'uncertain']
uncertain_data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485 entries, 20154 to 20638
# Data columns (total 4 columns):
# id            485 non-null object
# room          485 non-null object
# filename      485 non-null object
# image_path    485 non-null object
# dtypes: object(4)
# memory usage: 18.9+ KB

# %%
# then merge (on id) with base_data_cat to get 'original' room

uncert_with_base = pd.merge(uncertain_data_cat, base_data_cat, 
                            how='left', on=['id', 'filename'], 
                            suffixes=('_uncertain', '_base'))

uncert_with_base = uncert_with_base[['id', 'room_uncertain', 'room_base',
                                     'filename','image_path_uncertain',
                                     'image_path_base']]

uncert_with_base.info()

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 485 entries, 0 to 484
# Data columns (total 6 columns):
# id                      485 non-null object
# room_uncertain          485 non-null object
# room_base               483 non-null object
# filename                485 non-null object
# image_path_uncertain    485 non-null object
# image_path_base         483 non-null object
# dtypes: object(6)
# memory usage: 26.5+ KB

# %%
uncert_with_base.head(12)
# Out:
#                                           id room_uncertain   room_base  \
# 0   0004f3c83558a0033af8c4cb6fc421d50f383ae9      uncertain       study
# 1   00159cfba55720a60b93ad428b147b0c047302f9      uncertain  diningroom
# 2   01723a29323dd1e3eb2686dd8cef4a6bce343859      uncertain       empty
# 3   0232125f31767e2638c31b5837a73695f9a7c379      uncertain       study
# 4   02651bc091644ade28bf797241506e5fd3004449      uncertain  livingroom
# 5   0274daeec5b54cfff4923b255071f37afe9468f9      uncertain       study
# 6   02a55bf3e3f81df999b6afde2c1cecdebeaca619      uncertain       front
# 7   042b853e3d4a362a21870c13982bc181b63e11c9      uncertain     kitchen
# 8   044f5d4ddc6cb1db54aabc970bd686f4409b38b9      uncertain     kitchen
# 9   04a85d9ef447bbe372b7559d09ae52c3f0dce099      uncertain       empty
# 10  0500626f9d10ae3f6553d035a57af0e5fa0272ab      uncertain    misc_ext
# 11  050476d7fdb3df5de54123ac53e16315206a5c1c      uncertain       study
#
#                                         filename  \
# 0   0004f3c83558a0033af8c4cb6fc421d50f383ae9.jpg
# 1   00159cfba55720a60b93ad428b147b0c047302f9.jpg
# 2   01723a29323dd1e3eb2686dd8cef4a6bce343859.jpg
# 3   0232125f31767e2638c31b5837a73695f9a7c379.jpg
# 4   02651bc091644ade28bf797241506e5fd3004449.jpg
# 5   0274daeec5b54cfff4923b255071f37afe9468f9.jpg
# 6   02a55bf3e3f81df999b6afde2c1cecdebeaca619.jpg
# 7   042b853e3d4a362a21870c13982bc181b63e11c9.jpg
# 8   044f5d4ddc6cb1db54aabc970bd686f4409b38b9.jpg
# 9   04a85d9ef447bbe372b7559d09ae52c3f0dce099.jpg
# 10  0500626f9d10ae3f6553d035a57af0e5fa0272ab.jpg
# 11  050476d7fdb3df5de54123ac53e16315206a5c1c.jpg
#
#                                  image_path_uncertain  \
# 0   ./data/base_data/uncertain/0004f3c83558a0033af...
# 1   ./data/base_data/uncertain/00159cfba55720a60b9...
# 2   ./data/base_data/uncertain/01723a29323dd1e3eb2...
# 3   ./data/base_data/uncertain/0232125f31767e2638c...
# 4   ./data/base_data/uncertain/02651bc091644ade28b...
# 5   ./data/base_data/uncertain/0274daeec5b54cfff49...
# 6   ./data/base_data/uncertain/02a55bf3e3f81df999b...
# 7   ./data/base_data/uncertain/042b853e3d4a362a218...
# 8   ./data/base_data/uncertain/044f5d4ddc6cb1db54a...
# 9   ./data/base_data/uncertain/04a85d9ef447bbe372b...
# 10  ./data/base_data/uncertain/0500626f9d10ae3f655...
# 11  ./data/base_data/uncertain/050476d7fdb3df5de54...
#
#                                       image_path_base
# 0   ./data/base_data/study/0004f3c83558a0033af8c4c...
# 1   ./data/base_data/diningroom/00159cfba55720a60b...
# 2   ./data/base_data/empty/01723a29323dd1e3eb2686d...
# 3   ./data/base_data/study/0232125f31767e2638c31b5...
# 4   ./data/base_data/livingroom/02651bc091644ade28...
# 5   ./data/base_data/study/0274daeec5b54cfff4923b2...
# 6   ./data/base_data/front/02a55bf3e3f81df999b6afd...
# 7   ./data/base_data/kitchen/042b853e3d4a362a21870...
# 8   ./data/base_data/kitchen/044f5d4ddc6cb1db54aab...
# 9   ./data/base_data/empty/04a85d9ef447bbe372b7559...
# 10  ./data/base_data/misc_ext/0500626f9d10ae3f6553...
# 11  ./data/base_data/study/050476d7fdb3df5de54123a...

# %%
#uncert_with_base.to_csv(os.path.join(out_dir, 'uncert_with_base_x.csv'))

# %%
# find the missing 'room_base' data
uncert_with_base.loc[uncert_with_base['room_base'].isnull()]
# Out:
#                                                id room_uncertain room_base  \
# 439  09199e65fe2dd5c14dc1cc225e9fb602315dd751 (1)      uncertain       NaN
# 480  2a20626c9830eb9929c3497f399487e702b181b9 (1)      uncertain       NaN
#
#                                              filename  \
# 439  09199e65fe2dd5c14dc1cc225e9fb602315dd751 (1).jpg
# 480  2a20626c9830eb9929c3497f399487e702b181b9 (1).jpg
#
#                                   image_path_uncertain image_path_base
# 439  ./data/base_data/uncertain/09199e65fe2dd5c14dc...             NaN
# 480  ./data/base_data/uncertain/2a20626c9830eb9929c...             NaN

# %%
# on manual check - BOTH files are in ./uncertain with both xxxx.jpg AND xxxx (1).jpg
# versions of the name
# they are duplicates - we can delete the xxxx (1).jpg files


idx_to_delete = []   # was [439,480]
path_to_delete = []
for img in idx_to_delete:
    path_to_delete.append(uncert_with_base.iloc[img,4])

for file in path_to_delete:
    try: 
        os.remove(file)
        print('deleted file {}'.format(file))
    except OSError:
        pass

# %%
# Now recatalogue, and remerge...
uncertain_data_cat = nutil.build_catalogue('./data/base_data/')
uncertain_data_cat = uncertain_data_cat.loc[uncertain_data_cat['room'] == 'uncertain']
uncertain_data_cat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 20154 to 20636
# Data columns (total 4 columns):
# id            483 non-null object
# room          483 non-null object
# filename      483 non-null object
# image_path    483 non-null object
# dtypes: object(4)
# memory usage: 18.9+ KB

# %%
uncert_with_base = pd.merge(uncertain_data_cat, base_data_cat, 
                            how='left', on=['id', 'filename'], 
                            suffixes=('_uncertain', '_base'))

uncert_with_base = uncert_with_base[['id', 'room_uncertain', 'room_base',
                                     'filename','image_path_uncertain',
                                     'image_path_base']]

uncert_with_base.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 482
# Data columns (total 6 columns):
# id                      483 non-null object
# room_uncertain          483 non-null object
# room_base               483 non-null object
# filename                483 non-null object
# image_path_uncertain    483 non-null object
# image_path_base         483 non-null object
# dtypes: object(6)
# memory usage: 26.4+ KB

# %%
#uncert_with_base.to_csv(os.path.join(out_dir, 'uncert_with_base_x.csv'))

# %% [markdown]
# ### 6. After re-classifying 'uncertain' images - catalogue again
#
#
# After a pause (time to sleep on it), go to the `uncertain/` folder and reclassify all the images by placing them into the **correct** classification folder.
#
# The catalogue again, and merge with the `uncertain` df to have a catalogue of all uncertain and reclassified images, and their 'before' and 'after' reclassification labels

# %%
reclassified_data_cat = nutil.build_catalogue('./data/base_data/')
#reclassified_data_cat.to_csv(os.path.join(out_dir, '120318_reclassified_x.csv'))

# %%
reclassified_data_cat
# Out:
#                                              id      room  \
# 0      0000cb639c369a1d5b333d8c804cbfb628c31289  bathroom
# 1      000733430218ceea3108c989541c57fac2ba0ec9  bathroom
# 2      00098584f6a4e17fd099b93c13788606e398a989  bathroom
# 3      000edba64f83bce23027d2a4c213d354bb970439  bathroom
# 4      002154511c2145b7a1f28e680ef70b93c71f3089  bathroom
# 5      0024d3b7ded6abdcd8d2c9a91a963227dd47e4f9  bathroom
# 6      003457d1fb62155b4531aba3e5b39f4d57bed9f9  bathroom
# 7      0035742dfac3284819b412eb277cce498a52da79  bathroom
# 8      0038cad4553a9922d24a70a4d77abb9d2c1261f9  bathroom
# 9      0039e85363197bca4b7b7188fc97e962894a13c9  bathroom
# 10     003f5052b875f64f4f5ce99948ae87f35d44b009  bathroom
# 11     004011800a56d981628c1269e70e65e024085de9  bathroom
# 12     0042ef3acb52d3d438660247a94fc66a8e89c1e9  bathroom
# 13     00489c460959b4a3a328c2c0349dd3f6c312fc39  bathroom
# 14     005505d1c64c8128fa3595abb1000f9ea7e51959  bathroom
# 15     0060af05f71730efe5bd7cbd4eb5da8ddfa3b5c9  bathroom
# 16     00618a16e9742d519c378a39babf27977baafa19  bathroom
# 17     006679bd464bcf382089409c611cf061d69431f9  bathroom
# 18     007b8f99b24f9ba14ab97ac18d575fc0bc3a5d49  bathroom
# 19     007d0918d2bbca4c24da505ad4d9fd37d6d69b29  bathroom
# 20     00840251c3310a7a02ec7bfe14454474613e7899  bathroom
# 21     008c8ecb60b9617cff7b3e80f487d8704d0914f9  bathroom
# 22     008f1938edbfa3f7b2b5fea31072823b807f8629  bathroom
# 23     009e866e3eb114c3bc8579d780a4c333ddd38da9  bathroom
# 24     00af819588b69a9424153882d8ab9eb9cb0db1f9  bathroom
# 25     00da56e13e015b383effff3fe8560ae7fa7cb1f9  bathroom
# 26     00fd9ed80bc7fd342aa288ac089b65a727a699a9  bathroom
# 27     01127f8881f9ee0c5414cb64eda4011f9ffd6ee9  bathroom
# 28     011c734ba3011c3761772cda9eca6f711ed49919  bathroom
# 29     011f3ba4ba871dcf77d95b8121ca69e4d73cda19  bathroom
# ...                                         ...       ...
# 20607  214ab4ae0cd8a3f97b1a2edbae21ebb7f8ded799     study
# 20608  21cef4db1f1cdad328232a13b1106e32db70d819     study
# 20609  21eee00d6eece2092ab334479e2cd553dc9d70e9     study
# 20625  ./data/base_data/study/26a9954d1c4c734215f8731...
# 20626  ./data/base_data/study/26bad216f9dde6d8d6fb82c...
# 20627  ./data/base_data/study/26bc3b1aadacbba316ff620...
# 20628  ./data/base_data/study/28346ccc8a8028df8924f6d...
# 20629  ./data/base_data/study/293e356c9ed7816044549b1...
# 20630  ./data/base_data/study/2966382b2054e47f789b405...
# 20631  ./data/base_data/study/29856bebdd64240b9d24c08...
# 20632  ./data/base_data/study/29a8215f53dff909068541b...
# 20633  ./data/base_data/study/29b6c6ecf93497cdbf45d99...
# 20634  ./data/base_data/study/2a24c3ca978306a58dd74ac...
# 20635  ./data/base_data/study/2aee0a825784c921be5e501...
# 20636  ./data/base_data/study/2b961bd1b1924d1fd8a6228...
#
# [20637 rows x 4 columns]

# %%
# merge with uncertain to have records of all reclassified images.

reclass_with_base_and_uncertain = pd.merge(uncert_with_base, reclassified_data_cat,
                                          how='left', on=['id', 'filename'],
                                          suffixes=('_','_reclass'))

reclass_with_base_and_uncertain.rename(columns={'room':'room_reclass', 'image_path':'image_path_reclass'}, inplace=True)

reclass_with_base_and_uncertain = reclass_with_base_and_uncertain[['id', 'room_reclass','room_base',
                                                                    'room_uncertain','filename', 
                                                                  'image_path_reclass', 'image_path_base',
                                                                  'image_path_uncertain']]

# %%
#reclass_with_base_and_uncertain.to_csv(os.path.join(out_dir, '120318_reclass_and_base_x.csv'))

# %%
reclass_with_base_and_uncertain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 483 entries, 0 to 482
# Data columns (total 8 columns):
# id                      483 non-null object
# room_reclass            483 non-null object
# room_base               483 non-null object
# room_uncertain          483 non-null object
# filename                483 non-null object
# image_path_reclass      483 non-null object
# image_path_base         483 non-null object
# image_path_uncertain    483 non-null object
# dtypes: object(8)
# memory usage: 34.0+ KB

# %% [markdown]
# There are 483 images that were classed as 'uncertain' and then reclassified.

# %%
reclass_with_base_and_uncertain.columns
# Out:
# Index(['id', 'room_reclass', 'room_base', 'room_uncertain', 'filename',
#        'image_path_reclass', 'image_path_base', 'image_path_uncertain'],
#       dtype='object')

# %%
reclass_with_base_and_uncertain.loc[reclass_with_base_and_uncertain['room_reclass'] == 
                                    reclass_with_base_and_uncertain['room_base']].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24 entries, 17 to 436
# Data columns (total 8 columns):
# id                      24 non-null object
# room_reclass            24 non-null object
# room_base               24 non-null object
# room_uncertain          24 non-null object
# filename                24 non-null object
# image_path_reclass      24 non-null object
# image_path_base         24 non-null object
# image_path_uncertain    24 non-null object
# dtypes: object(8)
# memory usage: 1.7+ KB

# %% [markdown]
# 24 of the 'uncertain' images were reclassified the same as their original classification, the rest were changed to a different classification.

# %%
reclass_with_base_and_uncertain.loc[reclass_with_base_and_uncertain['room_reclass'] == 'exclude']
# Out:
#                                            id room_reclass   room_base  \
# 31   0536c9b06e3cbdc9d774452b0cfe9b93c16862cd      exclude       study
# 39   0551c5c22af07e8415df25737180a04e09174bf5      exclude    misc_int
# 52   056db3637dcca6dd50591c5918ee09d99411037b      exclude    misc_int
# 73   05976d9d1875b56e2e1e35b0dbf261ac88f758e7      exclude    misc_int
# 74   0597b8d45b7715cf78ce068a79c632dfabc3d5f5      exclude    misc_int
# 91   05cc91249666961dddac850be5a4c68bacd586bc      exclude    misc_ext
# 107  060598fb5174ff14cd8acd3bb7dc394070667f67      exclude    misc_ext
# 128  063cdec519be5b7fcfaeedec6c20e9973d9ef512      exclude    misc_ext
# 161  06a0e94c11f29e6281aefeb35aab42b28dc617af      exclude    misc_int
# 211  06f8f4294a8b14cc97107be282542d4c5edbd750      exclude  diningroom
# 212  06f8fc217f1fbbc2679e673aa4ec7f440c3a4734      exclude  diningroom
# 230  0723347c492bb7662cf823b10bd992d37a889d90      exclude    misc_int
# 250  075af6bd08cfa8df307c7db55530eb086bab724d      exclude    misc_int
# 264  077c12c944933f3ba55376c289beffbbc9e86a73      exclude       study
# 267  0786107d2ad0170bfceeb9631572b5ef6b164326      exclude    misc_int
# 270  07892a0754037100bcdda2c1c97ffbb4481afc4f      exclude    misc_ext
# 288  07b82356000c0cac4e8ffd07fb23798844f3bd4a      exclude    misc_ext
# 318  0800fd67360982cd797e37858a3b7d234d5ead1e      exclude    misc_int
# 323  0809b13193562c13aa23b098b82d049b50b54485      exclude    misc_ext
# 324  080d60ac740e34a4bdbcb766f5b4d6a931d370f0      exclude    misc_ext
# 365  087b769ecdda012478dbb21d6c79e63e8178c9a7      exclude    misc_ext
# 385  089b7bc0a4b7a68f9fc9e1bf51558567e0c0f328      exclude    misc_int
# 392  08a8ecf30d0c2d1b21c091c78e78a5d980d9a779      exclude    misc_ext
# 438  0916e04d3dc12167388d2369e23959bf06d2c9f8      exclude    misc_int
# 460  0957c41f5a2140afea55e726c66a28acf7564f1f      exclude    misc_int
# 478  29d5de6732a5b8ad0488924d9e44cd8c94d2c569      exclude     bedroom
#
#     room_uncertain                                      filename  \
# 31       uncertain  0536c9b06e3cbdc9d774452b0cfe9b93c16862cd.jpg
# 39       uncertain  0551c5c22af07e8415df25737180a04e09174bf5.jpg
# 52       uncertain  056db3637dcca6dd50591c5918ee09d99411037b.jpg
# 73       uncertain  05976d9d1875b56e2e1e35b0dbf261ac88f758e7.jpg
# 74       uncertain  0597b8d45b7715cf78ce068a79c632dfabc3d5f5.jpg
# 91       uncertain  05cc91249666961dddac850be5a4c68bacd586bc.jpg
# 107      uncertain  060598fb5174ff14cd8acd3bb7dc394070667f67.jpg
# 128      uncertain  063cdec519be5b7fcfaeedec6c20e9973d9ef512.jpg
# 161      uncertain  06a0e94c11f29e6281aefeb35aab42b28dc617af.jpg
# 211      uncertain  06f8f4294a8b14cc97107be282542d4c5edbd750.jpg
# 212      uncertain  06f8fc217f1fbbc2679e673aa4ec7f440c3a4734.jpg
# 230      uncertain  0723347c492bb7662cf823b10bd992d37a889d90.jpg
# 250      uncertain  075af6bd08cfa8df307c7db55530eb086bab724d.jpg
# 264      uncertain  077c12c944933f3ba55376c289beffbbc9e86a73.jpg
# 267      uncertain  0786107d2ad0170bfceeb9631572b5ef6b164326.jpg
# 270      uncertain  07892a0754037100bcdda2c1c97ffbb4481afc4f.jpg
# 288      uncertain  07b82356000c0cac4e8ffd07fb23798844f3bd4a.jpg
# 318      uncertain  0800fd67360982cd797e37858a3b7d234d5ead1e.jpg
# 323      uncertain  0809b13193562c13aa23b098b82d049b50b54485.jpg
# 324      uncertain  080d60ac740e34a4bdbcb766f5b4d6a931d370f0.jpg
# 365      uncertain  087b769ecdda012478dbb21d6c79e63e8178c9a7.jpg
# 385      uncertain  089b7bc0a4b7a68f9fc9e1bf51558567e0c0f328.jpg
# 392      uncertain  08a8ecf30d0c2d1b21c091c78e78a5d980d9a779.jpg
# 438      uncertain  0916e04d3dc12167388d2369e23959bf06d2c9f8.jpg
# 460      uncertain  0957c41f5a2140afea55e726c66a28acf7564f1f.jpg
# 478      uncertain  29d5de6732a5b8ad0488924d9e44cd8c94d2c569.jpg
#
#                                     image_path_reclass  \
# 31   ./data/base_data/exclude/0536c9b06e3cbdc9d7744...
# 39   ./data/base_data/exclude/0551c5c22af07e8415df2...
# 52   ./data/base_data/exclude/056db3637dcca6dd50591...
# 73   ./data/base_data/exclude/05976d9d1875b56e2e1e3...
# 74   ./data/base_data/exclude/0597b8d45b7715cf78ce0...
# 91   ./data/base_data/exclude/05cc91249666961dddac8...
# 107  ./data/base_data/exclude/060598fb5174ff14cd8ac...
# 128  ./data/base_data/exclude/063cdec519be5b7fcfaee...
# 161  ./data/base_data/exclude/06a0e94c11f29e6281aef...
# 211  ./data/base_data/exclude/06f8f4294a8b14cc97107...
# 212  ./data/base_data/exclude/06f8fc217f1fbbc2679e6...
# 230  ./data/base_data/exclude/0723347c492bb7662cf82...
# 250  ./data/base_data/exclude/075af6bd08cfa8df307c7...
# 264  ./data/base_data/exclude/077c12c944933f3ba5537...
# 267  ./data/base_data/exclude/0786107d2ad0170bfceeb...
# 270  ./data/base_data/exclude/07892a0754037100bcdda...
# 288  ./data/base_data/exclude/07b82356000c0cac4e8ff...
# 318  ./data/base_data/exclude/0800fd67360982cd797e3...
# 323  ./data/base_data/exclude/0809b13193562c13aa23b...
# 324  ./data/base_data/exclude/080d60ac740e34a4bdbcb...
# 365  ./data/base_data/exclude/087b769ecdda012478dbb...
# 385  ./data/base_data/exclude/089b7bc0a4b7a68f9fc9e...
# 392  ./data/base_data/exclude/08a8ecf30d0c2d1b21c09...
# 438  ./data/base_data/exclude/0916e04d3dc12167388d2...
# 460  ./data/base_data/exclude/0957c41f5a2140afea55e...
# 478  ./data/base_data/exclude/29d5de6732a5b8ad04889...
#
#                                        image_path_base  \
# 31   ./data/base_data/study/0536c9b06e3cbdc9d774452...
# 39   ./data/base_data/misc_int/0551c5c22af07e8415df...
# 52   ./data/base_data/misc_int/056db3637dcca6dd5059...
# 73   ./data/base_data/misc_int/05976d9d1875b56e2e1e...
# 74   ./data/base_data/misc_int/0597b8d45b7715cf78ce...
# 91   ./data/base_data/misc_ext/05cc91249666961dddac...
# 107  ./data/base_data/misc_ext/060598fb5174ff14cd8a...
# 128  ./data/base_data/misc_ext/063cdec519be5b7fcfae...
# 161  ./data/base_data/misc_int/06a0e94c11f29e6281ae...
# 211  ./data/base_data/diningroom/06f8f4294a8b14cc97...
# 212  ./data/base_data/diningroom/06f8fc217f1fbbc267...
# 230  ./data/base_data/misc_int/0723347c492bb7662cf8...
# 250  ./data/base_data/misc_int/075af6bd08cfa8df307c...
# 264  ./data/base_data/study/077c12c944933f3ba55376c...
# 267  ./data/base_data/misc_int/0786107d2ad0170bfcee...
# 270  ./data/base_data/misc_ext/07892a0754037100bcdd...
# 288  ./data/base_data/misc_ext/07b82356000c0cac4e8f...
# 318  ./data/base_data/misc_int/0800fd67360982cd797e...
# 323  ./data/base_data/misc_ext/0809b13193562c13aa23...
# 324  ./data/base_data/misc_ext/080d60ac740e34a4bdbc...
# 365  ./data/base_data/misc_ext/087b769ecdda012478db...
# 385  ./data/base_data/misc_int/089b7bc0a4b7a68f9fc9...
# 392  ./data/base_data/misc_ext/08a8ecf30d0c2d1b21c0...
# 438  ./data/base_data/misc_int/0916e04d3dc12167388d...
# 460  ./data/base_data/misc_int/0957c41f5a2140afea55...
# 478  ./data/base_data/bedroom/29d5de6732a5b8ad04889...
#
#                                   image_path_uncertain
# 31   ./data/base_data/uncertain/0536c9b06e3cbdc9d77...
# 39   ./data/base_data/uncertain/0551c5c22af07e8415d...
# 52   ./data/base_data/uncertain/056db3637dcca6dd505...
# 73   ./data/base_data/uncertain/05976d9d1875b56e2e1...
# 74   ./data/base_data/uncertain/0597b8d45b7715cf78c...
# 91   ./data/base_data/uncertain/05cc91249666961ddda...
# 107  ./data/base_data/uncertain/060598fb5174ff14cd8...
# 128  ./data/base_data/uncertain/063cdec519be5b7fcfa...
# 161  ./data/base_data/uncertain/06a0e94c11f29e6281a...
# 211  ./data/base_data/uncertain/06f8f4294a8b14cc971...
# 212  ./data/base_data/uncertain/06f8fc217f1fbbc2679...
# 230  ./data/base_data/uncertain/0723347c492bb7662cf...
# 250  ./data/base_data/uncertain/075af6bd08cfa8df307...
# 264  ./data/base_data/uncertain/077c12c944933f3ba55...
# 267  ./data/base_data/uncertain/0786107d2ad0170bfce...
# 270  ./data/base_data/uncertain/07892a0754037100bcd...
# 288  ./data/base_data/uncertain/07b82356000c0cac4e8...
# 318  ./data/base_data/uncertain/0800fd67360982cd797...
# 323  ./data/base_data/uncertain/0809b13193562c13aa2...
# 324  ./data/base_data/uncertain/080d60ac740e34a4bdb...
# 365  ./data/base_data/uncertain/087b769ecdda012478d...
# 385  ./data/base_data/uncertain/089b7bc0a4b7a68f9fc...
# 392  ./data/base_data/uncertain/08a8ecf30d0c2d1b21c...
# 438  ./data/base_data/uncertain/0916e04d3dc12167388...
# 460  ./data/base_data/uncertain/0957c41f5a2140afea5...
# 478  ./data/base_data/uncertain/29d5de6732a5b8ad048...

# %% [markdown]
# And some of the images were chosen for exclusion and placed in an `exclude` folder. We wil look at these in a separate workbook.
