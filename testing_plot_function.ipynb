# %%
# %matplotlib inline

import numpy as np
import pandas as pd

import nested_plot as nplot

import seaborn as sns
sns.set()

# %%
image_df = pd.read_csv('data_catalogues/processing_2018-03-08_14-20-00/120318_reclass_and_base.csv', index_col=0)
image_df.head()
# Out:
#                                          id room_reclass   room_base  \
# 0  0004f3c83558a0033af8c4cb6fc421d50f383ae9   livingroom       study
# 1  00159cfba55720a60b93ad428b147b0c047302f9      kitchen  diningroom
# 2  01723a29323dd1e3eb2686dd8cef4a6bce343859     misc_int       empty
# 3  0232125f31767e2638c31b5837a73695f9a7c379     misc_int       study
# 4  02651bc091644ade28bf797241506e5fd3004449      bedroom  livingroom
#
#   room_uncertain                                      filename  \
# 0      uncertain  0004f3c83558a0033af8c4cb6fc421d50f383ae9.jpg
# 1      uncertain  00159cfba55720a60b93ad428b147b0c047302f9.jpg
# 2      uncertain  01723a29323dd1e3eb2686dd8cef4a6bce343859.jpg
# 3      uncertain  0232125f31767e2638c31b5837a73695f9a7c379.jpg
# 4      uncertain  02651bc091644ade28bf797241506e5fd3004449.jpg
#
#                                   image_path_reclass  \
# 0  ./data/base_data/livingroom/0004f3c83558a0033a...
# 1  ./data/base_data/kitchen/00159cfba55720a60b93a...
# ...

# %%
interior_rooms = ['bathroom',
                  'bedroom',
                  'conservatory', 
                  'diningroom',
                  'empty',
                  'entrance',
                  'graphic', 
                  'kitchen',
                  'livingroom', 
                  'misc_int', 
                  'study']

data = image_df.loc[(image_df['room_reclass'].isin(interior_rooms))]
data.sample(4)
# Out:
#                                            id room_reclass room_base  \
# 78   05a96a1dc724d356081ccfa7449138dd32e7390f      graphic  misc_ext
# 99   05e53be771a50fe02600c0da17bf7d80b0caca47      bedroom  misc_int
# 432  090531726d60b63302da13242f07514b31e20a0c     misc_int  bathroom
# 138  065cc1aa770ae14c3609c494284df12d93994c5c      graphic  misc_int
#
#     room_uncertain                                      filename  \
# 78       uncertain  05a96a1dc724d356081ccfa7449138dd32e7390f.jpg
# 99       uncertain  05e53be771a50fe02600c0da17bf7d80b0caca47.jpg
# 432      uncertain  090531726d60b63302da13242f07514b31e20a0c.jpg
# 138      uncertain  065cc1aa770ae14c3609c494284df12d93994c5c.jpg
#
#                                     image_path_reclass  \
# 78   ./data/base_data/graphic/05a96a1dc724d356081cc...
# 99   ./data/base_data/bedroom/05e53be771a50fe02600c...
# 432  ./data/base_data/misc_int/090531726d60b63302da...
# 138  ./data/base_data/graphic/065cc1aa770ae14c3609c...
#
# ...

# %%
label_fn = nplot.label_before_after
label_info = {'before': 'room_base',
              'after': 'room_reclass'}


nplot.image_grid(data, image_path='image_path_reclass',  image_size='xl', save=True,
           fig_title='Reclassified images', fill_grid=True, f_stem='Reclassified_',
          label_info=label_info, label_fn=label_fn, annotate=True,
                output_dir = './image_grids/')
# Out:
# /Users/Chris/anaconda3/envs/nested/lib/python3.6/site-packages/matplotlib/figure.py:1743: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "
